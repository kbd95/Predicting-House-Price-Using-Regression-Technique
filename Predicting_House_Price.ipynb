# %% [markdown]
# #                          Predicting House Prices
#   Using Advance Regression

# %% [markdown]
# # Importing Library

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline

# %% [markdown]
# # Load Dataset

# %%
df1=pd.read_csv("/home/ritesh/Desktop/Project/project/train.csv")
df1.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
df=df1.copy()

# %%
#Shape of train data
df.shape
# Out:
# (1460, 81)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
df_num = df.select_dtypes(exclude=['object'])
df_num.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# 0              0          0            0         0        0       2    2008
# 1              0          0            0         0        0       5    2007
# 2              0          0            0         0        0       9    2008
# 3            272          0            0         0        0       2    2006
# 4              0          0            0         0        0      12    2008
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000
#
# [5 rows x 38 columns]

# %%
df_catg = df.select_dtypes(include=['object'])
df_catg.head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1  ... GarageType GarageFinish GarageQual GarageCond  \
# 0      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 1      Veenker      Feedr  ...     Attchd          RFn         TA         TA
# 2      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 3      Crawfor       Norm  ...     Detchd          Unf         TA         TA
# 4      NoRidge       Norm  ...     Attchd          RFn         TA         TA
#
#   PavedDrive PoolQC Fence MiscFeature SaleType SaleCondition
# 0          Y    NaN   NaN         NaN       WD        Normal
# 1          Y    NaN   NaN         NaN       WD        Normal
# 2          Y    NaN   NaN         NaN       WD        Normal
# 3          Y    NaN   NaN         NaN       WD       Abnorml
# 4          Y    NaN   NaN         NaN       WD        Normal
#
# [5 rows x 43 columns]

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
y= pd.DataFrame(df["SalePrice"])
#y.shape

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
df= df.drop(["Id"],axis=1)
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave   NaN      Reg
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 1457          70       RL         66.0     9042   Pave   NaN      Reg
# 1458          20       RL         68.0     9717   Pave   NaN      Reg
# 1459          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# 0            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1            Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# 2            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 3            Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 4            Lvl    AllPub       FR2  ...        0    NaN    NaN         NaN
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 1455         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1456         Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# 1457         Lvl    AllPub    Inside  ...        0    NaN  GdPrv        Shed
# 1458         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1459         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0          0      2    2008        WD         Normal     208500
# 1          0      5    2007        WD         Normal     181500
# 2          0      9    2008        WD         Normal     223500
# 3          0      2    2006        WD        Abnorml     140000
# 4          0     12    2008        WD         Normal     250000
# ...      ...    ...     ...       ...            ...        ...
# 1455       0      8    2007        WD         Normal     175000
# 1456       0      2    2010        WD         Normal     210000
# 1457    2500      5    2010        WD         Normal     266500
# 1458       0      4    2010        WD         Normal     142125
# 1459       0      6    2008        WD         Normal     147500
#
# [1460 rows x 80 columns]

# %% [markdown]
# # Analysis on Target Variable

# %% [markdown]
# The saleprice has appreciable positive skewness, deviates from the normal distribution and shows peakedness.  Now, we need to tranform this variable and make it normal distribution.

# %%
plt.subplots(figsize=(12,9))
sns.distplot(df["SalePrice"],fit=stats.norm)
# Out:
# <AxesSubplot:xlabel='SalePrice'>

# %%
(mu,sigma)=stats.norm.fit(df["SalePrice"])
mu,sigma
# Out:
# (180921.19589041095, 79415.29188606751)

# %%
#plot wih distribution
plt.legend(["normal.dist.($/mu-${:.2f}and($/sigma-${:.2f}".format(mu,sigma)],loc="best")
plt.ylabel("frequency")
fig = plt.figure
stats.probplot(df["SalePrice"],plot=plt)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Here we use log for target variable to make more normal distribution

# %%
df["SalePrice"] = np.log1p(df["SalePrice"])
#check again for normal distribution
plt.subplots(figsize=(12,9))
sns.distplot(df["SalePrice"],fit=stats.norm)
# Out:
# <AxesSubplot:xlabel='SalePrice'>

# %%
mu,sigma=stats.norm.fit(df["SalePrice"])
#plot with distribution
plt.legend(["normal dist.($\mu=${:.2f}and$\sigma=${:2f}".format(mu,sigma)],loc="best")
fig=plt.figure
stats.probplot(df["SalePrice"],plot=plt)
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
var = "YearBuilt"
data = pd.concat([y, df[var]], axis=1)
f,ax = plt.subplots(figsize =(20,12))
plt.xticks(rotation=90)
fig = sns.boxplot(x=var,y="SalePrice",data=data)
plt.title(" YearBuilt on SalePrice")
fig.axis(ymin=0,ymax=755000)
# Out:
# (-0.5, 111.5, 0.0, 755000.0)

# %% [markdown]
# There is no much big impact of year Built on SalePrice

# %%
var = "BsmtFullBath"
data = pd.concat([y, df[var]], axis=1)
f,ax = plt.subplots(figsize=(9,9))
fig = sns.boxplot(x=var,y="SalePrice",data=data)
plt.title("Impact of BsmtFullBath on SalePrice")
fig.axis(ymin=0,ymax=755000)
# Out:
# (-0.5, 3.5, 0.0, 755000.0)

# %%
var = "OverallQual"
data = pd.concat([y, df[var]], axis=1)
f,ax = plt.subplots(figsize=(9,9))
fig = sns.boxplot(x=var,y="SalePrice",data=data)
plt.title("Impact ofOverallQual on SalePrice")
fig.axis(ymin=0,ymax=755000)
# Out:
# (-0.5, 9.5, 0.0, 755000.0)

# %% [markdown]
# The above plot clearly suggest that if the Overall Qualities are high, the Sale prices is also increases.

# %%
var = "FullBath"
data = pd.concat([y, df[var]], axis=1)
f,ax = plt.subplots(figsize=(9,9))
fig = sns.boxplot(x=var,y="SalePrice",data=data)
plt.title("Impact of FullBath(above grade) on SalePrice",color ="red")
fig.axis(ymin=0,ymax=755000)
# Out:
# (-0.5, 3.5, 0.0, 755000.0)

# %% [markdown]
# The above graph shows that if number of bathroom increases then sale price also increases.

# %%
var = "MoSold"
data = pd.concat([y, df[var]], axis=1)
f,ax = plt.subplots(figsize=(9,9))
fig = sns.boxplot(x=var,y="SalePrice",data=data)
plt.title("Impact of Month of Sold on SalePrice",color ="red")
fig.axis(ymin=0,ymax=755000)
# Out:
# (-0.5, 11.5, 0.0, 755000.0)

# %% [markdown]
# Month of sold does not impact on sale price.

# %% [markdown]
# # Time Series Analysis

# %%
data= df['YearBuilt'].value_counts().reset_index(name="YearBuilt")
data.columns = ["YearBuilt","Count"]
plt.figure(figsize=(18,8))
c= plt.bar(data["YearBuilt"],data["Count"],align="center")
plt.title("House Built Per Year")
plt.xlabel("YearBuilt")
plt.ylabel("No. of House")
plt.show()

# %%
data1 = df[["YearBuilt","SalePrice"]].groupby(["YearBuilt"],as_index = True).mean().plot(figsize= (20,9),color = "blue")
plt.title("Sale Price decrease and increase per year")
plt.show()
time = data1.get_figure()
time.savefig("Time.png")

# %% [markdown]
# # Correlation Between Train Attributes

# %%
corr = df.corr()
corr.style.background_gradient(cmap="coolwarm").set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col3 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col4 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col5 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col6 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col7 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col8 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col9 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col10 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col13 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col14 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col15 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col16 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col17 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col18 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col19 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col20 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col21 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col22 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col23 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col24 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col25 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col26 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col27 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col28 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col29 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col30 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col31 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col32 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col33 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col34 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col35 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow0_col36 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col2 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col3 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col4 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col5 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col6 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col7 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col8 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col9 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col10 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col11 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col12 {
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col13 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col14 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col15 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col16 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col17 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col18 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col19 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col20 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col21 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_d1bc8254_f7d9_11ea_be4e_00f48dea7dfbrow1_col22 {
#             background-color:  #

# %% [markdown]
# # Highly Correleted Train Attributes with SalePrice

# %%
top_feature = corr.index[abs(corr["SalePrice"]>0.5)]
plt.subplots(figsize=(12,8))
H_corr = df[top_feature].corr()
sns.heatmap(H_corr,annot=True)
plt.show()

# %% [markdown]
# Here OverallQual is highly correlated with target feature of SalePrice by 82%

# %%
#import warnings
#warnings.simplefilter("ignore")
#col = ["SalePrice","OverallQual","GrLivArea","GarageCars","TotalBsmtSF","FullBath","TotRmsAbvGrd","YearBuilt"]
#sns.set(style="ticks")
#sns.pairplot(df[col],size=4, kind = "reg")

# %%
print("Most important feature related to target variable")
corr.sort_values(["SalePrice"],ascending=False, inplace=True)
corr.SalePrice
# Out:
# Most important feature related to target variable
# SalePrice        1.000000
# OverallQual      0.817185
# GrLivArea        0.700927
# GarageCars       0.680625
# GarageArea       0.650888
# TotalBsmtSF      0.612134
# 1stFlrSF         0.596981
# FullBath         0.594771
# YearBuilt        0.586570
# YearRemodAdd     0.565608
# GarageYrBlt      0.541073
# TotRmsAbvGrd     0.534422
# Fireplaces       0.489450
# MasVnrArea       0.430809
# BsmtFinSF1       0.372023
# LotFrontage      0.355879
# WoodDeckSF       0.334135
# OpenPorchSF      0.321053
# 2ndFlrSF         0.319300
# HalfBath         0.313982
# LotArea          0.257320
# BsmtFullBath     0.236224
# BsmtUnfSF        0.221985
# BedroomAbvGr     0.209043
# ScreenPorch      0.121208
# PoolArea         0.069798
# MoSold           0.057330
# 3SsnPorch        0.054900
# BsmtFinSF2       0.004832
# BsmtHalfBath    -0.005149
# MiscVal         -0.020021
# OverallCond     -0.036868
# YrSold          -0.037263
# LowQualFinSF    -0.037963
# MSSubClass      -0.073959
# KitchenAbvGr    -0.147548
# EnclosedPorch   -0.149050
# Name: SalePrice, dtype: float64

# %% [markdown]
# # Find The Missing Value

# %%
## First lets handle Categorical features of train data which are missing
features_nan=[feature for feature in df.columns if df[feature].isnull().sum()>1 and df[feature].dtypes=='O']

for feature in features_nan:
    print("{}: {}% missing values".format(feature,np.round(df[feature].isnull().mean(),4)))
# Out:
# Alley: 0.9377% missing values
# MasVnrType: 0.0055% missing values
# BsmtQual: 0.0253% missing values
# BsmtCond: 0.0253% missing values
# BsmtExposure: 0.026% missing values
# BsmtFinType1: 0.0253% missing values
# BsmtFinType2: 0.026% missing values
# FireplaceQu: 0.4726% missing values
# GarageType: 0.0555% missing values
# GarageFinish: 0.0555% missing values
# GarageQual: 0.0555% missing values
# GarageCond: 0.0555% missing values
# PoolQC: 0.9952% missing values
# Fence: 0.8075% missing values
# MiscFeature: 0.963% missing values

# %%
## Replace missing value with a new label for train data
def replace_cat_feature(df,features_nan):
    data=df.copy()
    data[features_nan]=data[features_nan].fillna('Missing')
    return data

df=replace_cat_feature(df,features_nan)

df[features_nan].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
## Replace missing value with a new label for test data
def replace_cat_feature(df_test,features_nan):
    data=df_test.copy()
    data[features_nan]=data[features_nan].fillna('Missing')
    return data

df_test=replace_cat_feature(df,features_nan)

df_test[features_nan].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
## Now lets check for numerical variables of train data that contains missing values
numerical_with_nan=[feature for feature in df.columns if df[feature].isnull().sum()>1 and df[feature].dtypes!='O']

## We will print the numerical nan variables and percentage of missing values

for feature in numerical_with_nan:
    print("{}: {}% missing value".format(feature,np.around(df[feature].isnull().mean(),4)))
# Out:
# LotFrontage: 0.1774% missing value
# MasVnrArea: 0.0055% missing value
# GarageYrBlt: 0.0555% missing value

# %%
## Replacing the numerical Missing Values

for feature in numerical_with_nan:
    ## We will replace by using median since there are outliers
    median_value=df[feature].median()
    
    ## create a new feature to capture nan values
    df[feature+'nan']=np.where(df[feature].isnull(),1,0)
    df[feature].fillna(median_value,inplace=True)
    
df[numerical_with_nan].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
#Missing value in train data
plt.figure(figsize=(8,8))
sns.heatmap(df.isnull())
plt.show()

# %%
col = df_catg.columns
col
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
for c in col:
    lbl = LabelEncoder() 
    lbl.fit(list(df[c].values)) 
    df[c] = lbl.transform(list(df[c].values))

# %% [markdown]
# # Preparing data for prediction

# %%
#Take targate variable into y
y = df['SalePrice']

# %%
#Delete the saleprice
del df['SalePrice']

# %%
#Take their values in X and y
X = df.values
y = y.values

# %%
# Split data into train and test formate
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)

# %% [markdown]
# # Linear Regression

# %%
#from sklearn.model_selection import train_test_split
#x_train,x_test,y_train,y_test = train_test_split(X, y, test_size=0.20,random_state=0)

# %%
X_train.shape,y_train.shape
# Out:
# ((1168, 82), (1168,))

# %%
from sklearn.metrics import explained_variance_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
def errorScore(pred_y,y_test):
    result = []
    exp_var = "Explained variance of model: %.2f" %explained_variance_score(pred_y,y_test)
    R2_score = "R-square result: %.2f" %r2_score(pred_y,y_test)
    mse = "Mean squard error: %.2f" %mean_squared_error(pred_y,y_test)
    rmse = "RMSE: %2f" %np.sqrt(mean_squared_error(pred_y,y_test))
    result.append(exp_var)
    result.append(R2_score)
    result.append(mse)
    result.append(rmse)
    return result

# %%
predcted_y_test =regressor.predict(X_test)
predcted_y_train =regressor.predict(X_train)

# %%
print("Simple regression on test set :",errorScore(predcted_y_test,y_test))
print("Simple regression on train set :",errorScore(predcted_y_train,y_train))
# Out:
# Simple regression on test set : ['Explained variance of model: 0.87', 'R-square result: 0.87', 'Mean squard error: 0.02', 'RMSE: 0.135177']
# Simple regression on train set : ['Explained variance of model: 0.87', 'R-square result: 0.87', 'Mean squard error: 0.02', 'RMSE: 0.135621']

# %%
print( " Test accuracy  %.7f " %regressor.score(X_test, y_test))
# Out:
#  Test accuracy  0.8909551

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge
alpha = [0.1,0.01,0.02,0.001,0.001,0.0001,0.00001,0.0001]
RidgeReg = Ridge(0.001,max_iter=1000)
RidgeReg.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.001, max_iter=1000)

# %%
predcted_y_test =RidgeReg.predict(X_test)
predcted_y_train =RidgeReg.predict(X_train)
print("Simple regression on test set :",errorScore(predcted_y_test,y_test))
print("Simple regression on train set :",errorScore(predcted_y_train,y_train))
# Out:
# Simple regression on test set : ['Explained variance of model: 0.87', 'R-square result: 0.87', 'Mean squard error: 0.02', 'RMSE: 0.135176']
# Simple regression on train set : ['Explained variance of model: 0.87', 'R-square result: 0.87', 'Mean squard error: 0.02', 'RMSE: 0.135621']

# %%
print( " Test accuracy  %.5f" %RidgeReg.score(X_test, y_test))
# Out:
#  Test accuracy  0.89096

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso
lassReg = Lasso(alpha=0.001, max_iter=1000)
lassReg.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.001)

# %%
pred_las_y_test = lassReg.predict(X_test)
predcted_y_train = lassReg.predict(X_train)
print("Lasso regression on test:" ,errorScore(pred_las_y_test,y_test))
print("lasso regression on train set :",errorScore(predcted_y_train,y_train))
# Out:
# Lasso regression on test: ['Explained variance of model: 0.88', 'R-square result: 0.88', 'Mean squard error: 0.02', 'RMSE: 0.130873']
# lasso regression on train set : ['Explained variance of model: 0.86', 'R-square result: 0.86', 'Mean squard error: 0.02', 'RMSE: 0.137586']

# %%
print( " Test accuracy  %.2f " %lassReg.score(X_test, y_test))
# Out:
#  Test accuracy  0.90

# %% [markdown]
# # Elastic Net

# %%
from sklearn.linear_model import ElasticNet 
ElasticNetReg = ElasticNet(alpha=0.01,max_iter=10000)
ElasticNetReg.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=0.01, max_iter=10000)

# %%
predcted_y_test =ElasticNetReg.predict(X_test)
predcted_y_train =ElasticNetReg.predict(X_train)
print("Elastic regression on test set :",errorScore(predcted_y_test,y_test))
print("Elastic regression on train set :",errorScore(predcted_y_train,y_train))
# Out:
# Elastic regression on test set : ['Explained variance of model: 0.87', 'R-square result: 0.87', 'Mean squard error: 0.02', 'RMSE: 0.135487']
# Elastic regression on train set : ['Explained variance of model: 0.84', 'R-square result: 0.84', 'Mean squard error: 0.02', 'RMSE: 0.144842']

# %%
print( " Test  accuracy  %.2f " %ElasticNetReg.score(X_test, y_test))
# Out:
#  Test  accuracy  0.89

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0)
dec_tree = regressor.fit(X_train, y_train)

# %%
predcted_y_test =dec_tree.predict(X_test)
predcted_y_train =dec_tree.predict(X_train)
print("Decision Tree regression on test set :",errorScore(predcted_y_test,y_test))
print("Decision Tree regression on train set :",errorScore(predcted_y_train,y_train))
# Out:
# Decision Tree regression on test set : ['Explained variance of model: 0.77', 'R-square result: 0.77', 'Mean squard error: 0.04', 'RMSE: 0.201343']
# Decision Tree regression on train set : ['Explained variance of model: 1.00', 'R-square result: 1.00', 'Mean squard error: 0.00', 'RMSE: 0.000000']

# %%
print("Test accuracy: %.2f" %dec_tree.score(X_test,y_test))
# Out:
# Test accuracy: 0.76

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
random_model = RandomForestRegressor(n_estimators=1000)
random_model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=1000)

# %%
predcted_y_test = random_model.predict(X_test)
predcted_y_train = random_model.predict(X_train)

# %%
print("Random forest regressor on test set: ",errorScore(predcted_y_test,y_test))
print("Random forest regression on train set:", errorScore(predcted_y_train,y_train))
# Out:
# Random forest regressor on test set:  ['Explained variance of model: 0.87', 'R-square result: 0.87', 'Mean squard error: 0.02', 'RMSE: 0.131489']
# Random forest regression on train set: ['Explained variance of model: 0.98', 'R-square result: 0.98', 'Mean squard error: 0.00', 'RMSE: 0.053776']

# %%
print("Test accuracy: %.2f " %random_model.score(X_test,y_test))
# Out:
# Test accuracy: 0.90

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor
Gradient_BR = GradientBoostingRegressor(n_estimators=100,max_depth=4)
Gradient_BR.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(max_depth=4)

# %%
pred_XGB_y_test = Gradient_BR.predict(X_test)
predcted_y_train = Gradient_BR.predict(X_train)

# %%
print("Gradient Boodting regressor on test set:",errorScore(pred_XGB_y_test,y_test))
print("Gradient Boosting regressor on train set:",errorScore(predcted_y_train,y_train))
# Out:
# Gradient Boodting regressor on test set: ['Explained variance of model: 0.90', 'R-square result: 0.90', 'Mean squard error: 0.01', 'RMSE: 0.119056']
# Gradient Boosting regressor on train set: ['Explained variance of model: 0.98', 'R-square result: 0.98', 'Mean squard error: 0.00', 'RMSE: 0.055012']

# %%
print("Test accuracy:%.2f "%Gradient_BR.score(X_test,y_test))
# Out:
# Test accuracy:0.92

# %% [markdown]
# # Feature Engineering

# %%
#TotalBath
df['TotalBath'] = (df['FullBath'] + df['HalfBath'] + df['BsmtFullBath'] + df['BsmtHalfBath'])

#TotalPorch
df['TotalPorch'] = (df['OpenPorchSF'] + df['3SsnPorch'] + df['EnclosedPorch'] + df['ScreenPorch'] + df['WoodDeckSF'])

# %%
#Modeling happen during the sale year
df["RecentRemodel"] = (df["YearRemodAdd"] == df["YrSold"]) * 1

#House sold in the year it was built
df["NewHouse"] = (df["YearBuilt"] == df["YrSold"]) * 1

#HasPool
df['HasPool'] = df['PoolArea'].apply(lambda x: 1 if x > 0 else 0)

# %%
#HasFireplaces
df['HasFirePlace'] = df['Fireplaces'].apply(lambda x: 1 if x > 0 else 0)

#Has2ndFloor
df['Has2ndFloor'] = df['2ndFlrSF'].apply(lambda x: 1 if x > 0 else 0)

#HasGarage
df['HasGarage'] = df['GarageArea'].apply(lambda x: 1 if x > 0 else 0)

# %%
#HasBsmnt
df['HasBsmnt'] = df['TotalBsmtSF'].apply(lambda x: 1 if x > 0 else 0)

# %%
from sklearn.ensemble import GradientBoostingRegressor
Gradient_BR = GradientBoostingRegressor(n_estimators=100,max_depth=4)
Gradient_BR.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(max_depth=4)

# %%
pred_XGB_y_test = Gradient_BR.predict(X_test)
predcted_y_train = Gradient_BR.predict(X_train)

# %%
print("Gradient Boodting regressor on test set:",errorScore(pred_XGB_y_test,y_test))
print("Gradient Boosting regressor on train set:",errorScore(predcted_y_train,y_train))
# Out:
# Gradient Boodting regressor on test set: ['Explained variance of model: 0.90', 'R-square result: 0.90', 'Mean squard error: 0.01', 'RMSE: 0.120192']
# Gradient Boosting regressor on train set: ['Explained variance of model: 0.98', 'R-square result: 0.98', 'Mean squard error: 0.00', 'RMSE: 0.055012']

# %%
print("Test accuracy:%.2f "%Gradient_BR.score(X_test,y_test))
# Out:
# Test accuracy:0.91
